# %% [markdown]
# <a href="https://colab.research.google.com/github/sakaleshhubli/AI/blob/main/06_Linear_Regression_Using_SKlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
url = 'https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.shape
# Out:
# (40, 2)

# %%
# x train should be 2d array coz the LR fxn expects it as a parameter
x = df[["Experience Years"]]
y = df["Salary"]

# %%
plt.scatter(x_train, y_train, c='r', s = 15, marker = 'x')
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.title("Salary vs Experience Years")
plt.grid()
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.scatter(x_train, y_train, c='r', s = 15, marker = 'x')
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.title("Befor Applying LR")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(x_train, y_train, c='r', s = 15, marker = 'x')
plt.plot(x_test, y_pred, c='b', linewidth=2)
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.title("After Applying LR")
plt.grid()

# %%
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R^2 Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 23709808.22969958
# R^2 Score: 0.9603774998811886

# %%
print("Intercept:", model.intercept_)
print("Slope:", model.coef_[0])
# Out:
# Intercept: 26745.258594539584
# Slope: 9377.036510115739

# %%
years = float(input("Enter years of experience: "))
predicted_salary = model.predict([[years]])
print(f"Predicted Salary for {years} years of experience is ₹{predicted_salary[0]:,.2f}")
# Out:
# Enter years of experience: 5.5
# Predicted Salary for 5.5 years of experience is ₹78,318.96
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
